# %%
#importing dependencies-mediapipe and opencv
# !pip install mediapipe opencv-python

# %%
#import dependencies
import mediapipe as mp #gives us all pose estimated libraries and mediapipe solutions
import cv2
import numpy as np
mp_drawing=mp.solutions.drawing_utils #gives us drawing utilities
mp_pose=mp.solutions.pose #importing pose estimation models using mp_pose variable

# %%
#video feed
cap=cv2.VideoCapture(0)  
while cap.isOpened():
    ret,frame=cap.read()
    cv2.imshow('Mediapipe feed',frame) #ret-return variable,frame-image from our webcam
#imshow-gives a pop up text that allows us to visualize a particular image
    if cv2.waitKey(10) & 0xFF==ord('q'): #breaking out of our feed
        break

cap.release()  #action after beaking feed
cv2.destroyAllWindows()

# %%
#MAKE DETECTIONS
cap=cv2.VideoCapture(0)  
with mp_pose.Pose(min_detection_confidence=0.75,min_tracking_confidence=0.75) as pose:   #accessing our pos estimation model
#in abv stmt we maintain the confidence for detections,incr incase of more specific details and viceversa 
    while cap.isOpened():
        ret,frame=cap.read()

    #detect stuff and render and recolor image to rgb
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB) #mediapipe -rgb;opencv-bgr
        image.flags.writeable=False

    #make detection
        results=pose.process(image)

    #recolor back to bgr
        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
        

        #render detections
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(100,150,250),thickness=2,circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(50,125,66),thickness=2,circle_radius=2)) #landmark drawing spec and connection drawing spec
    
        cv2.imshow('Mediapipe feed',image) #ret-return variable,frame-image from our webcam
#imshow-gives a pop up text that allows us to visualize a particular image
        if cv2.waitKey(10) & 0xFF==ord('q'): #breaking out of our feed
            break

    cap.release()  #action after beaking feed
    cv2.destroyAllWindows()
# Out:
# C:\Users\prana\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
#MAKE DETECTIONS
#video feed
cap=cv2.VideoCapture(0)  
with mp_pose.Pose(min_detection_confidence=0.75,min_tracking_confidence=0.75) as pose:   #accessing our pos estimation model
#in abv stmt we maintain the confidence for detections,incr incase of more specific details and viceversa 
    while cap.isOpened():
        ret,frame=cap.read()

    #detect stuff and render and recolor image to rgb
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB) #mediapipe -rgb;opencv-bgr
        image.flags.writeable=False

    #make detection
        results=pose.process(image)

    #recolor back to bgr
        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

        #extract landmarks
        try:
            landmarks=result.pose_landmarks.landmark#incase of no intention to take detections we can pass
        except:
            pass

            
        #render detections
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(100,150,250),thickness=2,circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(50,125,66),thickness=2,circle_radius=2)) #landmark drawing spec and connection drawing spec
    
        cv2.imshow('Mediapipe feed',image) #ret-return variable,frame-image from our webcam
#imshow-gives a pop up text that allows us to visualize a particular image
        if cv2.waitKey(10) & 0xFF==ord('q'): #breaking out of our feed
            break

    cap.release()  #action after beaking feed
    cv2.destroyAllWindows()

# %%
import math

def calculate_angle(a, b, c):
    radians = math.atan2(c[1] - b[1], c[0] - b[0]) - math.atan2(a[1] - b[1], a[0] - b[0])
    angle = math.degrees(radians)
    if angle < 0:
        angle += 360
    return angle

# %%
#MAKE DETECTIONS
#video feed
cap=cv2.VideoCapture(0)  
with mp_pose.Pose(min_detection_confidence=0.75,min_tracking_confidence=0.75) as pose:   #accessing our pos estimation model
#in abv stmt we maintain the confidence for detections,incr incase of more specific details and viceversa 
    while cap.isOpened():
        ret,frame=cap.read()

    #detect stuff and render and recolor image to rgb
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB) #mediapipe -rgb;opencv-bgr
        image.flags.writeable=False

    #make detection
        results=pose.process(image)

    #recolor back to bgr
        image.flags.writeable=True
        image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)

        #extract landmarks
        try:
            landmarks=result.pose_landmarks.landmark#incase of no intention to take detections we can pass

            #get coordinates
            shoulder=[landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow=[landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist=[landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            angle=calculate_angle(shoulder,elbow,wrist)

        #visualize
            cv2.putText(image,str(angle),
                    tuple(np.multiply(elbow,[640,480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2,cv2.LINE_AAA)
            
        except:
            pass

            
        #render detections
        mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(100,150,250),thickness=2,circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(50,125,66),thickness=2,circle_radius=2)) #landmark drawing spec and connection drawing spec
    
        cv2.imshow('Mediapipe feed',image) #ret-return variable,frame-image from our webcam
#imshow-gives a pop up text that allows us to visualize a particular image
        if cv2.waitKey(10) & 0xFF==ord('q'): #breaking out of our feed
            break

    cap.release()  #action after beaking feed
    cv2.destroyAllWindows()
